# %%
import numpy as np, matplotlib.pyplot as plt
rank, freq = np.loadtxt('rank_freq.txt', usecols=(0,1), unpack=True)
plt.loglog(rank, freq, marker='.', linestyle='none')
plt.xlabel('rank'); plt.ylabel('frequency')
plt.tight_layout(); plt.savefig('zipf.png', dpi=200)
